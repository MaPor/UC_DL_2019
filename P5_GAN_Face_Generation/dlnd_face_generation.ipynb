# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
#!unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    data = datasets.ImageFolder(data_dir, transforms.Compose([transforms.Resize(image_size),transforms.ToTensor()]))
    # TODO: Implement function and return a dataloader
    
    dataloader_images = torch.utils.data.DataLoader(data,batch_size,shuffle=True)    
        
    return dataloader_images

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 64
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    
   
    min, max = feature_range
    x = x *(max-min)+ min

    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-1.)
# Max:  tensor(1.)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake
# ![image.png](attachment:image.png)

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
def conv(input_size,output_size, kernel_size, padding=1,stride=2,batch_norm=True):
    #Creates a concolutional layer, with optional bacht normalization
    layers = []
    conv_layers = nn.Conv2d(input_size,output_size,kernel_size,stride,padding, bias=False)
    #append conv layer
    layers.append(conv_layers)
    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(output_size))
    #using Sequential Container
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim  = conv_dim
        
        # 32x32 input
        self.conv1 = conv(3, conv_dim, kernel_size=4, batch_norm=False)   #first layer no batch_norm
        # 16x16 out
        self.conv2 = conv(conv_dim, conv_dim*2 , kernel_size=4) 
        # 8x8 out
        self.conv3 = conv(conv_dim * 2, conv_dim * 4, kernel_size=4) 
        # 4x4 out
        
        # finally a fully connected layer    
        self.fc = nn.Linear(conv_dim*4*4*4,1)   # Output 4x4 with depth:conv_dim*4   

    

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior

        # define feedforward behavior
        
        x = F.leaky_relu(self.conv1(x),0.2)
        x = F.leaky_relu(self.conv2(x),0.2)
        x = F.leaky_relu(self.conv3(x),0.2)
        
        #flatten
        x = x.view(-1, self.conv_dim*4*4*4)       #*4*4*4
        
        #final output layer
        x = self.fc(x)
   
        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`
# * Remember: o_size = stride * (in_size - 1) + kernel - 2 * padding
# ![image.png](attachment:image.png)

# %%
def deconv(input_size, output_size, kernel_size, padding=1, stride=2, batch_norm=True):
    layers = []
    transpose_conv = nn.ConvTranspose2d(input_size, output_size, kernel_size, padding=padding, stride=stride, bias=False)
    layers.append(transpose_conv)
    if batch_norm: 
        layers.append(nn.BatchNorm2d(output_size))
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim
        
        #first, fully -connected layer
        self.fc = nn.Linear(z_size, conv_dim*4*4*4)
        
        #transpose conv layer
        #self.t_conv0 = deconv(conv_dim*16, conv_dim*4, 4)
        self.t_conv1 = deconv(conv_dim*4, conv_dim*2, 4)
        self.t_conv2 = deconv(conv_dim*2, conv_dim, 4)
        self.t_conv3 = deconv(conv_dim, 3, 4, batch_norm=False)
         

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        
        #fully-connected + reshape
        out = self.fc(x)
        out = out.view(-1, self.conv_dim*4, 4, 4)  #(batch_size, depth, 4,4)
        
        #hidden transpose conv layers + relu
        #out= F.relu(self.t_conv0(out))
        out= F.relu(self.t_conv1(out))
        out= F.relu(self.t_conv2(out))
        
        #last layer + tanh activation
        out= self.t_conv3(out)
        out = F.tanh(out)
        
        return out

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
from torch.nn import init
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    if classname.find('Conv') != -1 or classname.find('Linear') != -1:
        init.normal_(m.weight.data, 0.0,0.02)
    # TODO: Apply initial weights to convolutional and linear layers
    
    return m

# %% [markdown]
# ## Build complete network
#
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 32
z_size = 160

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=160, out_features=2048, bias=True)
#   (t_conv1): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv2): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv3): Sequential(
#     (0): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    
    batch_size = D_out.size(0)
    labels = torch.ones(batch_size)*0.9
    if train_on_gpu:
        labels = labels.cuda()

    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss


def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size) # fake labels = 0
    if train_on_gpu:
        labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr=0.0001, betas=[0.35,0.999])
g_optimizer = optim.Adam(G.parameters(), lr=0.0001, betas= [0.35,0.999])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)
            if train_on_gpu:
                real_images = real_images.cuda()

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            d_optimizer.zero_grad()
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            
            if train_on_gpu:
                z = z.cuda()
            real_pred = D(real_images)
            real_l = real_loss(real_pred)
            fake_img = G(z)
            fake_pred = D(fake_img)
            fake_l = fake_loss(fake_pred)
            d_loss = fake_l + real_l
            d_loss.backward()
            d_optimizer.step()


            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
            fake_image = G(z)
            g_pred = D(fake_image)
            g_loss = real_loss(g_pred)
            g_loss.backward()
            g_optimizer.step()

            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 20


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   20] | d_loss: 1.4078 | g_loss: 0.7444
# Epoch [    1/   20] | d_loss: 0.6388 | g_loss: 1.7778
# Epoch [    1/   20] | d_loss: 0.5131 | g_loss: 2.1807
# Epoch [    1/   20] | d_loss: 0.4317 | g_loss: 2.7472
# Epoch [    1/   20] | d_loss: 0.5122 | g_loss: 2.1144
# Epoch [    1/   20] | d_loss: 0.5371 | g_loss: 2.8141
# Epoch [    1/   20] | d_loss: 0.5258 | g_loss: 3.0439
# Epoch [    1/   20] | d_loss: 0.4634 | g_loss: 2.6127
# Epoch [    1/   20] | d_loss: 0.5420 | g_loss: 2.3859
# Epoch [    1/   20] | d_loss: 0.6890 | g_loss: 2.4325
# Epoch [    1/   20] | d_loss: 0.5621 | g_loss: 1.8417
# Epoch [    1/   20] | d_loss: 0.7497 | g_loss: 1.1687
# Epoch [    1/   20] | d_loss: 0.7194 | g_loss: 1.7898
# Epoch [    1/   20] | d_loss: 0.6932 | g_loss: 1.4761
# Epoch [    1/   20] | d_loss: 0.7385 | g_loss: 2.0142
# Epoch [    1/   20] | d_loss: 0.9194 | g_loss: 1.2983
# Epoch [    1/   20] | d_loss: 0.7411 | g_loss: 1.1991
# Epoch [    1/   20] | d_loss: 0.8558 | g_loss: 1.4268
# Epoch [    1/   20] | d_loss: 0.9700 | g_loss: 1.3671
# Epoch [    1/   20] | d_loss: 0.9884 | g_loss: 1.1577
# Epoch [    1/   20] | d_loss: 1.0409 | g_loss: 1.3008
# Epoch [    1/   20] | d_loss: 1.0005 | g_loss: 1.0626
# Epoch [    1/   20] | d_loss: 1.1212 | g_loss: 0.7472
# Epoch [    1/   20] | d_loss: 1.0070 | g_loss: 1.2593
# Epoch [    1/   20] | d_loss: 1.1383 | g_loss: 1.2208
# Epoch [    1/   20] | d_loss: 1.1877 | g_loss: 0.9946
# Epoch [    1/   20] | d_loss: 1.0910 | g_loss: 0.9907
# Epoch [    1/   20] | d_loss: 1.0408 | g_loss: 1.0736
# Epoch [    1/   20] | d_loss: 0.9555 | g_loss: 1.6166
# Epoch [    2/   20] | d_loss: 1.1391 | g_loss: 0.6591
# Epoch [    2/   20] | d_loss: 1.1104 | g_loss: 1.0113
# Epoch [    2/   20] | d_loss: 1.0305 | g_loss: 1.3196
# Epoch [    2/   20] | d_loss: 1.2061 | g_loss: 1.0382
# Epoch [    2/   20] | d_loss: 1.0278 | g_loss: 1.4046
# Epoch [    2/   20] | d_loss: 1.1220 | g_loss: 0.9492
# Epoch [    2/   20] | d_loss: 1.2029 | g_loss: 1.3986
# Epoch [    2/   20] | d_loss: 1.0588 | g_loss: 1.1818
# Epoch [    2/   20] | d_loss: 1.3102 | g_loss: 0.8286
# Epoch [    2/   20] | d_loss: 1.1446 | g_loss: 1.0360
# Epoch [    2/   20] | d_loss: 1.1479 | g_loss: 1.1154
# Epoch [    2/   20] | d_loss: 1.0383 | g_loss: 1.3126
# Epoch [    2/   20] | d_loss: 1.1447 | g_loss: 0.8372
# Epoch [    2/   20] | d_loss: 1.1331 | g_loss: 1.2582
# Epoch [    2/   20] | d_loss: 1.0939 | g_loss: 0.9145
# Epoch [    2/   20] | d_loss: 1.3998 | g_loss: 0.8045
# Epoch [    2/   20] | d_loss: 1.1590 | g_loss: 1.0003
# Epoch [    2/   20] | d_loss: 1.0310 | g_loss: 1.0489
# Epoch [    2/   20] | d_loss: 1.0029 | g_loss: 0.9913
# Epoch [    2/   20] | d_loss: 1.0866 | g_loss: 1.3010
# Epoch [    2/   20] | d_loss: 0.9925 | g_loss: 1.1545
# Epoch [    2/   20] | d_loss: 1.1371 | g_loss: 1.1382
# Epoch [    2/   20] | d_loss: 1.0048 | g_loss: 0.8010
# Epoch [    2/   20] | d_loss: 1.1816 | g_loss: 1.5843
# Epoch [    2/   20] | d_loss: 1.1195 | g_loss: 1.0640
# Epoch [    2/   20] | d_loss: 0.9582 | g_loss: 1.3094
# Epoch [    2/   20] | d_loss: 1.1700 | g_loss: 0.9263
# Epoch [    2/   20] | d_loss: 1.0426 | g_loss: 0.9795
# Epoch [    2/   20] | d_loss: 1.0627 | g_loss: 1.1897
# Epoch [    3/   20] | d_loss: 1.2336 | g_loss: 1.0574
# Epoch [    3/   20] | d_loss: 1.1280 | g_loss: 0.8843
# Epoch [    3/   20] | d_loss: 1.0843 | g_loss: 0.8322
# Epoch [    3/   20] | d_loss: 1.1335 | g_loss: 1.4687
# Epoch [    3/   20] | d_loss: 1.0818 | g_loss: 1.1965
# Epoch [    3/   20] | d_loss: 1.1142 | g_loss: 1.0527
# Epoch [    3/   20] | d_loss: 1.1828 | g_loss: 1.0276
# Epoch [    3/   20] | d_loss: 1.1578 | g_loss: 0.9478
# Epoch [    3/   20] | d_loss: 1.2476 | g_loss: 1.1761
# Epoch [    3/   20] | d_loss: 1.0413 | g_loss: 1.1170
# Epoch [    3/   20] | d_loss: 1.2765 | g_loss: 0.9079
# Epoch [    3/   20] | d_loss: 1.1296 | g_loss: 1.5654
# Epoch [    3/   20] | d_loss: 1.0395 | g_loss: 1.2263
# Epoch [    3/   20] | d_loss: 1.2906 | g_loss: 0.8402
# Epoch [    3/   20] | d_loss: 1.0306 | g_loss: 1.2213
# Epoch [    3/   20] | d_loss: 1.0958 | g_loss: 1.6660
# Epoch [    3/   20] | d_loss: 1.0611 | g_loss: 1.3994
# Epoch [    3/   20] | d_loss: 1.1661 | g_loss: 1.3461
# Epoch [    3/   20] | d_loss: 1.0728 | g_loss: 1.2051
# Epoch [    3/   20] | d_loss: 1.1212 | g_loss: 1.0176
# Epoch [    3/   20] | d_loss: 1.1011 | g_loss: 1.1939
# Epoch [    3/   20] | d_loss: 1.0550 | g_loss: 1.2945
# Epoch [    3/   20] | d_loss: 1.0325 | g_loss: 1.2281
# Epoch [    3/   20] | d_loss: 0.9758 | g_loss: 1.2380
# Epoch [    3/   20] | d_loss: 1.1908 | g_loss: 1.1094
# Epoch [    3/   20] | d_loss: 1.2049 | g_loss: 1.4123
# Epoch [    3/   20] | d_loss: 1.1233 | g_loss: 1.1264
# Epoch [    3/   20] | d_loss: 1.1461 | g_loss: 1.0503
# Epoch [    3/   20] | d_loss: 1.0689 | g_loss: 1.0089
# Epoch [    4/   20] | d_loss: 1.8959 | g_loss: 2.5294
# Epoch [    4/   20] | d_loss: 1.0115 | g_loss: 1.0896
# Epoch [    4/   20] | d_loss: 1.3265 | g_loss: 1.1782
# Epoch [    4/   20] | d_loss: 1.0503 | g_loss: 0.9830
# Epoch [    4/   20] | d_loss: 0.9578 | g_loss: 1.2828
# Epoch [    4/   20] | d_loss: 1.3174 | g_loss: 0.5180
# Epoch [    4/   20] | d_loss: 1.0841 | g_loss: 0.9476
# Epoch [    4/   20] | d_loss: 0.9507 | g_loss: 1.4160
# Epoch [    4/   20] | d_loss: 1.1541 | g_loss: 0.9675
# Epoch [    4/   20] | d_loss: 0.8830 | g_loss: 1.3229
# Epoch [    4/   20] | d_loss: 0.7629 | g_loss: 1.8123
# Epoch [    4/   20] | d_loss: 1.0589 | g_loss: 1.1651
# Epoch [    4/   20] | d_loss: 1.0759 | g_loss: 1.1589
# Epoch [    4/   20] | d_loss: 1.3023 | g_loss: 1.0587
# Epoch [    4/   20] | d_loss: 0.7212 | g_loss: 1.4841
# Epoch [    4/   20] | d_loss: 1.1088 | g_loss: 0.8218
# Epoch [    4/   20] | d_loss: 0.9744 | g_loss: 1.5673
# Epoch [    4/   20] | d_loss: 0.9194 | g_loss: 1.0678
# Epoch [    4/   20] | d_loss: 0.9050 | g_loss: 1.4328
# Epoch [    4/   20] | d_loss: 1.1442 | g_loss: 1.0838
# Epoch [    4/   20] | d_loss: 1.1281 | g_loss: 1.0092
# Epoch [    4/   20] | d_loss: 1.0596 | g_loss: 1.1752
# Epoch [    4/   20] | d_loss: 1.0760 | g_loss: 1.6601
# Epoch [    4/   20] | d_loss: 0.9924 | g_loss: 1.1234
# Epoch [    4/   20] | d_loss: 0.9816 | g_loss: 1.4681
# Epoch [    4/   20] | d_loss: 0.9852 | g_loss: 1.5033
# Epoch [    4/   20] | d_loss: 1.1164 | g_loss: 0.9324
# Epoch [    4/   20] | d_loss: 0.9572 | g_loss: 1.0820
# Epoch [    4/   20] | d_loss: 1.4899 | g_loss: 2.0845
# Epoch [    5/   20] | d_loss: 1.0290 | g_loss: 2.0992
# Epoch [    5/   20] | d_loss: 1.1352 | g_loss: 1.1397
# Epoch [    5/   20] | d_loss: 0.9859 | g_loss: 1.0615
# Epoch [    5/   20] | d_loss: 0.9036 | g_loss: 1.0774
# Epoch [    5/   20] | d_loss: 0.8452 | g_loss: 1.4253
# Epoch [    5/   20] | d_loss: 1.0368 | g_loss: 0.9949
# Epoch [    5/   20] | d_loss: 1.1059 | g_loss: 1.5358
# Epoch [    5/   20] | d_loss: 0.9163 | g_loss: 1.3811
# Epoch [    5/   20] | d_loss: 1.0748 | g_loss: 1.1166
# Epoch [    5/   20] | d_loss: 0.9201 | g_loss: 1.3521
# Epoch [    5/   20] | d_loss: 1.1446 | g_loss: 0.9504
# Epoch [    5/   20] | d_loss: 0.9042 | g_loss: 1.2176
# Epoch [    5/   20] | d_loss: 1.0539 | g_loss: 0.9581
# Epoch [    5/   20] | d_loss: 0.9809 | g_loss: 1.1623
# Epoch [    5/   20] | d_loss: 1.1560 | g_loss: 1.1691
# Epoch [    5/   20] | d_loss: 0.8169 | g_loss: 1.3992
# Epoch [    5/   20] | d_loss: 1.1189 | g_loss: 1.1993
# Epoch [    5/   20] | d_loss: 0.9239 | g_loss: 1.2672
# Epoch [    5/   20] | d_loss: 0.9478 | g_loss: 1.3112
# Epoch [    5/   20] | d_loss: 0.9438 | g_loss: 0.7731
# Epoch [    5/   20] | d_loss: 0.8840 | g_loss: 1.0986
# Epoch [    5/   20] | d_loss: 0.9256 | g_loss: 1.1068
# Epoch [    5/   20] | d_loss: 0.7288 | g_loss: 1.7727
# Epoch [    5/   20] | d_loss: 0.9477 | g_loss: 1.3331
# Epoch [    5/   20] | d_loss: 0.8969 | g_loss: 1.5442
# Epoch [    5/   20] | d_loss: 0.9093 | g_loss: 1.0850
# Epoch [    5/   20] | d_loss: 1.0220 | g_loss: 1.3835
# Epoch [    5/   20] | d_loss: 0.9991 | g_loss: 1.2375
# Epoch [    7/   20] | d_loss: 0.9091 | g_loss: 1.5476
# Epoch [    7/   20] | d_loss: 0.9821 | g_loss: 1.0834
# Epoch [    7/   20] | d_loss: 0.9054 | g_loss: 1.1068
# Epoch [    7/   20] | d_loss: 0.8928 | g_loss: 1.3106
# Epoch [    7/   20] | d_loss: 0.8771 | g_loss: 1.3946
# Epoch [    7/   20] | d_loss: 1.3180 | g_loss: 1.7898
# Epoch [    7/   20] | d_loss: 1.0806 | g_loss: 1.2221
# Epoch [    7/   20] | d_loss: 0.8903 | g_loss: 1.7774
# Epoch [    7/   20] | d_loss: 1.0431 | g_loss: 1.6069
# Epoch [    7/   20] | d_loss: 0.9959 | g_loss: 1.2077
# Epoch [    7/   20] | d_loss: 0.9138 | g_loss: 1.2047
# Epoch [    7/   20] | d_loss: 0.8928 | g_loss: 1.1127
# Epoch [    7/   20] | d_loss: 0.8080 | g_loss: 1.6493
# Epoch [    7/   20] | d_loss: 0.9101 | g_loss: 1.4478
# Epoch [    7/   20] | d_loss: 0.6588 | g_loss: 1.8977
# Epoch [    8/   20] | d_loss: 1.0939 | g_loss: 1.3004
# Epoch [    8/   20] | d_loss: 0.8621 | g_loss: 1.6848
# Epoch [    8/   20] | d_loss: 1.0222 | g_loss: 1.2823
# Epoch [    8/   20] | d_loss: 1.1473 | g_loss: 1.1810
# Epoch [    8/   20] | d_loss: 0.9370 | g_loss: 1.4984
# Epoch [    8/   20] | d_loss: 0.7632 | g_loss: 1.3777
# Epoch [    8/   20] | d_loss: 0.8233 | g_loss: 1.5839
# Epoch [    8/   20] | d_loss: 0.8976 | g_loss: 1.3926
# Epoch [    8/   20] | d_loss: 0.8804 | g_loss: 1.3025
# Epoch [    8/   20] | d_loss: 0.9416 | g_loss: 1.5975
# Epoch [    8/   20] | d_loss: 0.7946 | g_loss: 1.5820
# Epoch [    8/   20] | d_loss: 0.9524 | g_loss: 1.4458
# Epoch [    8/   20] | d_loss: 0.8353 | g_loss: 1.4558
# Epoch [    8/   20] | d_loss: 0.9415 | g_loss: 1.0032
# Epoch [    8/   20] | d_loss: 0.9481 | g_loss: 1.3056
# Epoch [    8/   20] | d_loss: 1.0732 | g_loss: 1.4195
# Epoch [    8/   20] | d_loss: 1.0339 | g_loss: 1.0219
# Epoch [    8/   20] | d_loss: 0.9744 | g_loss: 1.5168
# Epoch [    8/   20] | d_loss: 0.9020 | g_loss: 1.2243
# Epoch [    8/   20] | d_loss: 0.8123 | g_loss: 1.7890
# Epoch [    8/   20] | d_loss: 0.8905 | g_loss: 1.5177
# Epoch [    8/   20] | d_loss: 0.9885 | g_loss: 0.9092
# Epoch [    8/   20] | d_loss: 0.8809 | g_loss: 1.0558
# Epoch [    8/   20] | d_loss: 0.9289 | g_loss: 1.1179
# Epoch [    8/   20] | d_loss: 1.0575 | g_loss: 1.7241
# Epoch [    8/   20] | d_loss: 0.8099 | g_loss: 1.5647
# Epoch [    8/   20] | d_loss: 1.2369 | g_loss: 2.3663
# Epoch [    8/   20] | d_loss: 1.0954 | g_loss: 1.0544
# Epoch [    8/   20] | d_loss: 1.0730 | g_loss: 1.0537
# Epoch [   15/   20] | d_loss: 0.8179 | g_loss: 1.6807
# Epoch [   15/   20] | d_loss: 0.6100 | g_loss: 1.7731
# Epoch [   15/   20] | d_loss: 0.6654 | g_loss: 1.9332
# Epoch [   15/   20] | d_loss: 0.8407 | g_loss: 2.0337
# Epoch [   15/   20] | d_loss: 0.6497 | g_loss: 2.0721
# Epoch [   15/   20] | d_loss: 0.7361 | g_loss: 1.5982
# Epoch [   15/   20] | d_loss: 0.7823 | g_loss: 1.8421
# Epoch [   15/   20] | d_loss: 0.8511 | g_loss: 1.3756
# Epoch [   15/   20] | d_loss: 0.8168 | g_loss: 2.2873
# Epoch [   15/   20] | d_loss: 0.8393 | g_loss: 1.2001
# Epoch [   15/   20] | d_loss: 0.9521 | g_loss: 2.4597
# Epoch [   15/   20] | d_loss: 0.7494 | g_loss: 1.5703
# Epoch [   15/   20] | d_loss: 0.6858 | g_loss: 1.3868
# Epoch [   15/   20] | d_loss: 1.1304 | g_loss: 2.0797
# Epoch [   15/   20] | d_loss: 0.7330 | g_loss: 1.2051
# Epoch [   15/   20] | d_loss: 0.8375 | g_loss: 2.0117
# Epoch [   15/   20] | d_loss: 0.6652 | g_loss: 1.3631
# Epoch [   15/   20] | d_loss: 0.7460 | g_loss: 1.3709
# Epoch [   15/   20] | d_loss: 0.9264 | g_loss: 1.1037
# Epoch [   15/   20] | d_loss: 0.7432 | g_loss: 1.3979
# Epoch [   15/   20] | d_loss: 0.8124 | g_loss: 1.1950
# Epoch [   15/   20] | d_loss: 0.7284 | g_loss: 1.7406
# Epoch [   15/   20] | d_loss: 0.7253 | g_loss: 1.7919
# Epoch [   15/   20] | d_loss: 0.7356 | g_loss: 1.9423
# Epoch [   15/   20] | d_loss: 0.8579 | g_loss: 1.3154
# Epoch [   15/   20] | d_loss: 0.9039 | g_loss: 2.2662
# Epoch [   16/   20] | d_loss: 0.8173 | g_loss: 1.7140
# Epoch [   16/   20] | d_loss: 0.9525 | g_loss: 1.7074
# Epoch [   16/   20] | d_loss: 0.8950 | g_loss: 3.1188
# Epoch [   16/   20] | d_loss: 0.8994 | g_loss: 1.4988
# Epoch [   16/   20] | d_loss: 0.6427 | g_loss: 1.8098
# Epoch [   16/   20] | d_loss: 0.7202 | g_loss: 1.6301
# Epoch [   16/   20] | d_loss: 0.5947 | g_loss: 1.3120
# Epoch [   16/   20] | d_loss: 0.5375 | g_loss: 1.6214
# Epoch [   16/   20] | d_loss: 1.0913 | g_loss: 2.9937
# Epoch [   16/   20] | d_loss: 0.8519 | g_loss: 2.2211
# Epoch [   16/   20] | d_loss: 0.6797 | g_loss: 1.5981
# Epoch [   16/   20] | d_loss: 0.6514 | g_loss: 1.3181
# Epoch [   16/   20] | d_loss: 0.6363 | g_loss: 1.5293
# Epoch [   16/   20] | d_loss: 1.0574 | g_loss: 0.7494
# Epoch [   16/   20] | d_loss: 0.8010 | g_loss: 1.8801
# Epoch [   16/   20] | d_loss: 0.5141 | g_loss: 2.6465
# Epoch [   16/   20] | d_loss: 0.7794 | g_loss: 1.3690
# Epoch [   16/   20] | d_loss: 0.7751 | g_loss: 0.9017
# Epoch [   16/   20] | d_loss: 0.7207 | g_loss: 1.8665
# Epoch [   16/   20] | d_loss: 0.6080 | g_loss: 1.9206
# Epoch [   16/   20] | d_loss: 0.9897 | g_loss: 1.3008
# Epoch [   16/   20] | d_loss: 1.3981 | g_loss: 0.6794
# Epoch [   16/   20] | d_loss: 0.8483 | g_loss: 1.1950
# Epoch [   16/   20] | d_loss: 0.7106 | g_loss: 1.5721
# Epoch [   16/   20] | d_loss: 0.6536 | g_loss: 1.1323
# Epoch [   16/   20] | d_loss: 0.4506 | g_loss: 2.3335
# Epoch [   16/   20] | d_loss: 0.6732 | g_loss: 1.7591
# Epoch [   16/   20] | d_loss: 0.7141 | g_loss: 1.8676
# Epoch [   16/   20] | d_loss: 0.7267 | g_loss: 1.6242
# Epoch [   17/   20] | d_loss: 0.6377 | g_loss: 1.9569
# Epoch [   17/   20] | d_loss: 0.6447 | g_loss: 1.4958
# Epoch [   17/   20] | d_loss: 0.5340 | g_loss: 1.9362
# Epoch [   17/   20] | d_loss: 0.7052 | g_loss: 1.4924
# Epoch [   17/   20] | d_loss: 0.5146 | g_loss: 2.7601
# Epoch [   17/   20] | d_loss: 0.7373 | g_loss: 1.6012
# Epoch [   17/   20] | d_loss: 0.6461 | g_loss: 1.9860
# Epoch [   17/   20] | d_loss: 0.5593 | g_loss: 1.7258
# Epoch [   17/   20] | d_loss: 0.6767 | g_loss: 1.8336
# Epoch [   17/   20] | d_loss: 0.9028 | g_loss: 1.2600
# Epoch [   17/   20] | d_loss: 0.7355 | g_loss: 1.1879
# Epoch [   17/   20] | d_loss: 0.6498 | g_loss: 1.6293
# Epoch [   17/   20] | d_loss: 0.8606 | g_loss: 2.5211
# Epoch [   17/   20] | d_loss: 0.7618 | g_loss: 1.7077
# Epoch [   17/   20] | d_loss: 0.6916 | g_loss: 3.1075
# Epoch [   17/   20] | d_loss: 2.4203 | g_loss: 3.7588
# Epoch [   17/   20] | d_loss: 0.5790 | g_loss: 2.3761
# Epoch [   17/   20] | d_loss: 0.5790 | g_loss: 1.6589
# Epoch [   17/   20] | d_loss: 0.8828 | g_loss: 1.0301
# Epoch [   17/   20] | d_loss: 0.6530 | g_loss: 1.7322
# Epoch [   17/   20] | d_loss: 0.8660 | g_loss: 1.5597
# Epoch [   17/   20] | d_loss: 1.0559 | g_loss: 2.7128
# Epoch [   17/   20] | d_loss: 0.7617 | g_loss: 1.4089
# Epoch [   17/   20] | d_loss: 1.0462 | g_loss: 0.6588
# Epoch [   17/   20] | d_loss: 0.8057 | g_loss: 1.6987
# Epoch [   17/   20] | d_loss: 0.7222 | g_loss: 2.1715
# Epoch [   17/   20] | d_loss: 0.7816 | g_loss: 1.8477
# Epoch [   17/   20] | d_loss: 0.6780 | g_loss: 2.2588
# Epoch [   17/   20] | d_loss: 1.8875 | g_loss: 1.2679
# Epoch [   18/   20] | d_loss: 0.7025 | g_loss: 1.8390
# Epoch [   18/   20] | d_loss: 0.5139 | g_loss: 2.2194
# Epoch [   18/   20] | d_loss: 0.6173 | g_loss: 1.8125
# Epoch [   18/   20] | d_loss: 0.6691 | g_loss: 2.3227
# Epoch [   18/   20] | d_loss: 0.8218 | g_loss: 1.4145
# Epoch [   18/   20] | d_loss: 0.7109 | g_loss: 1.6146
# Epoch [   18/   20] | d_loss: 2.5983 | g_loss: 4.1779
# Epoch [   18/   20] | d_loss: 0.6911 | g_loss: 1.8293
# Epoch [   18/   20] | d_loss: 0.8038 | g_loss: 1.0703
# Epoch [   18/   20] | d_loss: 0.8769 | g_loss: 1.7280
# Epoch [   18/   20] | d_loss: 0.5321 | g_loss: 2.7444
# Epoch [   18/   20] | d_loss: 0.8568 | g_loss: 2.0182
# Epoch [   18/   20] | d_loss: 2.0429 | g_loss: 3.5794
# Epoch [   18/   20] | d_loss: 0.6501 | g_loss: 1.5422
# Epoch [   18/   20] | d_loss: 0.7744 | g_loss: 1.2965
# Epoch [   18/   20] | d_loss: 0.5634 | g_loss: 1.3714
# Epoch [   18/   20] | d_loss: 0.7486 | g_loss: 1.9185
# Epoch [   18/   20] | d_loss: 0.6442 | g_loss: 1.6204
# Epoch [   18/   20] | d_loss: 0.6857 | g_loss: 1.8381
# Epoch [   18/   20] | d_loss: 0.7374 | g_loss: 2.0114
# Epoch [   18/   20] | d_loss: 1.0612 | g_loss: 2.3657
# Epoch [   18/   20] | d_loss: 0.7661 | g_loss: 1.6276
# Epoch [   18/   20] | d_loss: 0.7128 | g_loss: 1.7088
# Epoch [   18/   20] | d_loss: 0.8586 | g_loss: 1.5981
# Epoch [   18/   20] | d_loss: 1.0252 | g_loss: 1.4764
# Epoch [   18/   20] | d_loss: 0.7317 | g_loss: 1.4789
# Epoch [   18/   20] | d_loss: 0.6186 | g_loss: 1.6341
# Epoch [   18/   20] | d_loss: 0.7299 | g_loss: 1.5415
# Epoch [   18/   20] | d_loss: 0.5698 | g_loss: 2.2498
# Epoch [   19/   20] | d_loss: 1.0321 | g_loss: 2.5343
# Epoch [   19/   20] | d_loss: 0.7284 | g_loss: 1.5119
# Epoch [   19/   20] | d_loss: 0.6614 | g_loss: 1.7509
# Epoch [   19/   20] | d_loss: 0.6773 | g_loss: 1.2902
# Epoch [   19/   20] | d_loss: 0.7373 | g_loss: 1.6183
# Epoch [   19/   20] | d_loss: 0.7676 | g_loss: 1.3821
# Epoch [   19/   20] | d_loss: 0.7145 | g_loss: 1.4919
# Epoch [   19/   20] | d_loss: 0.5872 | g_loss: 1.5544
# Epoch [   19/   20] | d_loss: 0.9232 | g_loss: 2.2161
# Epoch [   19/   20] | d_loss: 0.6920 | g_loss: 1.9324
# Epoch [   19/   20] | d_loss: 1.2563 | g_loss: 4.5304
# Epoch [   19/   20] | d_loss: 0.7336 | g_loss: 1.4104
# Epoch [   19/   20] | d_loss: 0.6792 | g_loss: 1.0917
# Epoch [   19/   20] | d_loss: 0.8340 | g_loss: 1.3031
# Epoch [   19/   20] | d_loss: 0.7060 | g_loss: 1.8024
# Epoch [   19/   20] | d_loss: 0.9637 | g_loss: 2.0117
# Epoch [   19/   20] | d_loss: 0.7128 | g_loss: 2.0519
# Epoch [   19/   20] | d_loss: 0.6052 | g_loss: 2.4137
# Epoch [   19/   20] | d_loss: 0.6646 | g_loss: 1.7956
# Epoch [   19/   20] | d_loss: 0.6828 | g_loss: 1.7730
# Epoch [   19/   20] | d_loss: 0.6847 | g_loss: 1.8562
# Epoch [   19/   20] | d_loss: 0.4963 | g_loss: 2.2683
# Epoch [   19/   20] | d_loss: 0.7911 | g_loss: 1.9573
# Epoch [   19/   20] | d_loss: 0.7688 | g_loss: 1.4776
# Epoch [   19/   20] | d_loss: 0.6893 | g_loss: 2.5666
# Epoch [   19/   20] | d_loss: 0.5669 | g_loss: 2.0106
# Epoch [   19/   20] | d_loss: 0.6568 | g_loss: 1.7562
# Epoch [   19/   20] | d_loss: 0.6031 | g_loss: 1.8133
# Epoch [   19/   20] | d_loss: 0.5891 | g_loss: 2.0787
# Epoch [   20/   20] | d_loss: 0.7082 | g_loss: 2.0262
# Epoch [   20/   20] | d_loss: 0.8187 | g_loss: 2.4430
# Epoch [   20/   20] | d_loss: 0.8318 | g_loss: 2.4387
# Epoch [   20/   20] | d_loss: 0.7139 | g_loss: 1.5878
# Epoch [   20/   20] | d_loss: 0.6021 | g_loss: 2.3389
# Epoch [   20/   20] | d_loss: 1.0455 | g_loss: 1.0732
# Epoch [   20/   20] | d_loss: 0.5512 | g_loss: 1.8329
# Epoch [   20/   20] | d_loss: 0.6947 | g_loss: 1.9104
# Epoch [   20/   20] | d_loss: 0.5149 | g_loss: 2.2323
# Epoch [   20/   20] | d_loss: 0.6897 | g_loss: 2.0643
# Epoch [   20/   20] | d_loss: 1.1065 | g_loss: 1.9214
# Epoch [   20/   20] | d_loss: 0.6183 | g_loss: 1.8210
# Epoch [   20/   20] | d_loss: 0.6293 | g_loss: 1.3867
# Epoch [   20/   20] | d_loss: 0.5642 | g_loss: 2.6365
# Epoch [   20/   20] | d_loss: 0.5809 | g_loss: 1.6154
# Epoch [   20/   20] | d_loss: 0.8373 | g_loss: 2.0952
# Epoch [   20/   20] | d_loss: 0.6685 | g_loss: 1.6535
# Epoch [   20/   20] | d_loss: 0.6721 | g_loss: 1.5755
# Epoch [   20/   20] | d_loss: 0.6344 | g_loss: 2.4488
# Epoch [   20/   20] | d_loss: 0.6680 | g_loss: 1.6039
# Epoch [   20/   20] | d_loss: 0.5841 | g_loss: 2.0656
# Epoch [   20/   20] | d_loss: 0.8636 | g_loss: 1.3623
# Epoch [   20/   20] | d_loss: 0.5629 | g_loss: 2.0781
# Epoch [   20/   20] | d_loss: 0.9735 | g_loss: 2.2489
# Epoch [   20/   20] | d_loss: 0.8239 | g_loss: 1.2215
# Epoch [   20/   20] | d_loss: 0.8162 | g_loss: 1.5947
# Epoch [   20/   20] | d_loss: 0.6171 | g_loss: 1.8528
# Epoch [   20/   20] | d_loss: 0.5037 | g_loss: 2.3887
# Epoch [   20/   20] | d_loss: 0.6789 | g_loss: 1.9453

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:**
#
# * to have a better diversity, the dataset should be more equal in black and white.
# * computation time vs. details ... deeper models can host more details
# * for a better optimization: Maybe the Wasserstein GAN (WGAN) could help....

# %% [markdown]
# **Results:**
#
# * 1st try: -> something is wrong here
# * 2nd try: -> better in terms of loss, but the generated pictures are bad
# * 3rd try: -> 10 epochs makes it no better
# * 4th try: -> found the error (typo in Generator optimizer: only the discriminator was optimized)

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
